-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [TodoApp]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 12/21/2022 7:52:33 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Todos]

-- %%
/****** Object:  Table [dbo].[Todos]    Script Date: 12/21/2022 7:52:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Todos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Title] [nvarchar](max) NOT NULL,
	[Completed] [bit] NOT NULL,
 CONSTRAINT [PK_Todos] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
INSERT [dbo].[__EFMigrationsHistory] ([MigrationId], [ProductVersion]) VALUES (N'20221210200305_InitCreate', N'7.0.0')
GO

-- %% [markdown]
-- # [dbo].[Todos]

-- %%
SET IDENTITY_INSERT [dbo].[Todos] ON 
INSERT [dbo].[Todos] ([Id], [Title], [Completed]) VALUES (2, N'task dois', 1)
INSERT [dbo].[Todos] ([Id], [Title], [Completed]) VALUES (3, N'task tres', 0)
INSERT [dbo].[Todos] ([Id], [Title], [Completed]) VALUES (5, N'task quatro', 0)
INSERT [dbo].[Todos] ([Id], [Title], [Completed]) VALUES (1023, N'este é o novo teste', 1)
INSERT [dbo].[Todos] ([Id], [Title], [Completed]) VALUES (1025, N'app docker-compose', 1)
SET IDENTITY_INSERT [dbo].[Todos] OFF
GO
